# %% [markdown]
# Sinh viên lưu file theo tên `MSSV_Tên.ipynb`.
#
# Nộp bài tại: https://forms.gle/5S8yrjXJ9F2cqcyV9

# %%
#import tại đây

# %% [markdown]
# #Series
# Tạo Series như yêu cầu:
#
# 1. ![hình 1.png](data:image/png;base64,...)
#
# 2. ![Hình 2.png](data:image/png;base64,...)
#
# 3. Index là tên tiếng Anh các tháng trong năm, data là số ngày tương ứng với index.

# %% [markdown]
# #DataFrame
# Tạo DataFrame như yêu cầu:
#
# 1. ![df1.png](data:image/png;base64,...)
# 2. ![df2.png](data:image/png;base64,...)
# 3. Bảng chân trị của toán tử AND.

# %% [markdown]
# #Tổng hợp
# Cho DataFrame mẫu như phần dưới, thực hiện các yêu cầu sau:
# 1. Thêm cột `UnitPrice`, giá trị toàn cột bằng 0.
# 2. Tính số lượng trung bình cột `Quantity`.
# 3. In ra kiểu của từng cột.
# 4. Lấy ra tất cả những dòng có `Quantity > 10` trong tháng 8/2025.

# %%
#dataframe mẫu
import numpy as np

date = np.datetime64('2025-09-19', 'D') + np.random.randint(-100, 100, size = 100)
product = np.random.choice(['Apple', 'Banana', 'Cherry', 'Durian'], size = 100)
quantity = np.random.randint(100, size = 100)

df = pd.DataFrame({'Date' : date, 'Product' : product, 'Quantity' : quantity})
